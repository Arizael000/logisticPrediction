# %%
import numpy as np
import pandas as pd
# ================================================================
# EJERCICIO 1: Operaciones aritméticas vectorizadas
# ----------------------------------------------------------------
# Dadas dos listas de precios de productos (precios_2023 y precios_2024) del mismo largo,
# calcula el cambio porcentual de cada producto entre ambos años usando vectorización.
# 
# Datos:
# precios_2023 = np.array([12.5, 8.3, 25.0, 14.2, 9.8])
# precios_2024 = np.array([13.0, 8.5, 27.5, 13.8, 10.1])
#
# PISTA: (precios_2024 - precios_2023) / precios_2023 * 100
#
# APLICACIÓN REAL: 
# Calcular rentabilidad de cartera, evolución de precios de acciones, o variación 
# de costos unitarios en millones de registros. La vectorización evita bucles lentos.
# ================================================================

# %%
precios_2023 = np.array([12.5, 8.3, 25.0, 14.2, 9.8])
precios_2024 = np.array([13.0, 8.5, 27.5, 13.8, 10.1])

# %%
print((precios_2024-precios_2023)/precios_2023*100)
# Out:
# [ 4.          2.40963855 10.         -2.81690141  3.06122449]

# %%
data = np.arange(1_000_000)
