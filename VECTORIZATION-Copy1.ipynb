# %%
# Ejercicio 1: Suma elemento a elemento
# -------------------------------------
# import numpy as np
# a = np.array([1, 2, 3, 4, 5])
# b = np.array([10, 20, 30, 40, 50])
# resultado = ...   # Tu código vectorizado aquí
# print(resultado)  # Esperado: [11 22 33 44 55]
