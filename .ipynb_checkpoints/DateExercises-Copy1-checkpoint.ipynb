# %%
# %% [markdown]
# # Pandas Datetime Exercises
# 
# Complete the exercises below by writing the appropriate pandas code after each description.
# 
# %% [code]
import pandas as pd
import numpy as np

# =============================================================================
# BASIC EXERCISES
# =============================================================================

"""
Exercise 1: Create a datetime object
- Create a pandas Timestamp for '2025-03-16 14:30:00'
- Print it and check its type
"""



"""
Exercise 2: Convert a string column to datetime
- Create a DataFrame with a column 'date_str': ['2023-01-01', '2023-02-15', '2023-03-20']
- Convert that column to datetime using pd.to_datetime()
- Print the dtypes to confirm
"""



"""
Exercise 3: Access datetime components
- Using the DataFrame from Exercise 2, extract year, month, day, and dayofweek as new columns
"""



"""
Exercise 4: Date arithmetic (timedelta)
- Create a column 'date' with values: '2023-01-01', '2023-02-01', '2023-03-01' (as datetime)
- Add 10 days to each date, store in a new column 'date_plus_10'
- Subtract the first date from the last to get the number of days difference
"""



"""
Exercise 5: Filter rows based on date
- Create a date range from '2023-01-01' to '2023-12-31' with daily frequency (use pd.date_range)
- Convert to a DataFrame with one column 'date'
- Add a random value column (use np.random.randn)
- Select all rows where the date is in March 2023
"""



# =============================================================================
# INTERMEDIATE EXERCISES
# =============================================================================

"""
Exercise 6: Set datetime as index and sort
- Create a DataFrame with dates: '2023-05-15', '2023-03-10', '2023-08-22' and values [10,20,30]
- Set the 'date' column as the index (after converting to datetime)
- Sort the index and display the DataFrame
"""



"""
Exercise 7: Resample time series data
- Create a DataFrame with a daily date range from '2023-01-01' to '2023-12-31' and a cumulative sum of random numbers
- Resample the data to monthly frequency, computing the mean for each month
- Also compute the sum per quarter
"""



"""
Exercise 8: Shifting and lagging
- Using the daily DataFrame from Exercise 7, create columns:
  - 'value_prev_day' (shift by 1)
  - 'value_next_day' (shift by -1)
- Compute the day‑over‑day difference
"""



"""
Exercise 9: Rolling window calculations
- Using the daily DataFrame from Exercise 7, compute a 7‑day rolling average of the value column
- Also compute a 30‑day rolling standard deviation
- Plot both the original and rolling averages (optional)
"""



"""
Exercise 10: Date ranges and periods
- Create a period index for the year 2023 with monthly frequency (use pd.period_range)
- Convert it to a datetime index and back to periods
"""



"""
Exercise 11: Handle time zones
- Create a Timestamp for '2025-03-16 12:00:00' and localize it to 'UTC'
- Convert it to 'US/Eastern'
- Create a DataFrame with a column of UTC timestamps and convert the whole column to 'Europe/London'
"""



"""
Exercise 12: Business days and custom offsets
- Create a date range consisting of only business days (Mon-Fri) for the year 2023
- Find the next business day after '2023-12-25' (Christmas)
- Create a custom offset that adds 2 business days
"""



# =============================================================================
# ADVANCED EXERCISES
# =============================================================================

"""
Exercise 13: Handling missing dates in time series
- Create a daily date range from '2023-01-01' to '2023-01-10'
- Intentionally remove some dates (e.g., keep only 5 random dates) and create a DataFrame with those as index, with random values
- Reindex the DataFrame to the full date range, filling missing values with forward fill
"""



"""
Exercise 14: Complex filtering with datetime conditions
- Create a DataFrame with a datetime index for every hour of 2023
- Add a column 'value' (random numbers)
- Select all rows that are:
  - In the first quarter (Jan-Mar)
  - AND between 9 AM and 5 PM (business hours)
  - AND on a weekday
"""



"""
Exercise 15: Grouping by time components
- Using the hourly DataFrame from Exercise 14, group by:
  - hour of the day and compute average value
  - day of the week and compute sum
  - month and compute median
"""



"""
Exercise 16: Custom business day calendar with holidays
- Define a list of holidays for 2023: ['2023-01-01', '2023-12-25']
- Create a custom business day offset that uses this holiday calendar
- Generate a date range for the first 10 business days of 2023 using this custom calendar
"""



"""
Exercise 17: Time zone aware resampling
- Create an hourly time series for 2023-03-12 to 2023-03-14 (around US DST change) with time zone 'US/Eastern'
- Resample to daily frequency and see how the DST transition affects the number of hours
"""



"""
Exercise 18: Date arithmetic with business days
- Calculate the number of business days between '2023-01-01' and '2023-12-31' using pd.bdate_range
- Also compute the number of actual days and compare
"""



"""
Exercise 19: Convert string column with mixed formats
- Create a DataFrame with a column 'mixed_dates': ['2023/01/15', '15-02-2023', 'March 20, 2023', '20230405']
- Convert all to datetime in a robust way (using pd.to_datetime with appropriate parameters)
"""



"""
Exercise 20: Extract week of year and quarter
- Using the daily DataFrame from Exercise 7, add columns for:
  - week of year
  - quarter
  - day of year
  - whether it's a weekend (True/False)
"""



"""
Exercise 21: Date offsets and anchoring
- Create a datetime index starting '2023-01-01' with 10 periods
- Add one month end offset to each date (MonthEnd)
- Find the last day of the current month for each date
"""



"""
Exercise 22: Conditional logic with dates
- Create a DataFrame with a date column and a value column
- Create a new column 'category' that labels each row as:
  - 'Q1' if the date is in Jan-Mar
  - 'Q2' if Apr-Jun
  - 'Q3' if Jul-Sep
  - 'Q4' if Oct-Dec
"""



"""
Exercise 23: Interpolate missing values in time series
- Create a time series with a few missing values (set some values to NaN)
- Use interpolation (time-based) to fill the missing values
"""



"""
Exercise 24: Find the closest date in a list
- Given a list of dates: ['2023-01-05', '2023-02-14', '2023-03-10', '2023-04-01']
- For a target date '2023-02-28', find which of the list dates is closest (in absolute days)
"""



"""
Exercise 25: Time until next event
- Create a DataFrame with event dates: ['2023-01-15', '2023-02-20', '2023-03-25']
- For a given evaluation date '2023-02-01', compute the number of days until the next event
"""



"""
Exercise 26: Complex resampling with custom aggregation
- Using the hourly DataFrame from Exercise 14, resample to 3-day frequency and apply multiple aggregations:
  - mean, min, max, and the number of non‑null values
"""



"""
Exercise 27: Parse dates automatically when reading CSV
- (Simulate) Create a CSV string with a date column and read it with parse_dates=True
- Demonstrate that the column becomes datetime
"""



"""
Exercise 28: Datetime difference in various units
- Create two date columns: 'start' and 'end'
- Compute the difference in days, seconds, and months (using numpy timedelta)
"""



"""
Exercise 29: Handle ambiguous times due to DST
- Create a time series that includes the ambiguous hour on the day DST ends (e.g., 2023-11-05 01:00 in US/Eastern)
- Localize with 'ambiguous' parameter set to 'infer' or a boolean array
"""



"""
Exercise 30: Build a complete ETL pipeline snippet
- Starting from raw strings: dates = ['2023-01-01', '2023-01-02', ...], values = [...]
- Convert to datetime, set as index, resample to weekly, fill missing, add rolling features, and plot
"""

# %%
