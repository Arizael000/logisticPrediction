# %% [markdown]
# Primero Realizamos un **EDA**

# %%
import pandas as pd
import matplotlib.pyplot as plt
#Cargamos el dataset
df = pd.read_csv("ventas_empresa_logistica.csv")
print("El tipo de dato de la columna producto es:",df["producto"].dtypes)
# Out:
# El tipo de dato de la columna producto es: object

# %% [markdown]
# Ver las primeras líneas

# %%
print(df.head())
# Out:
#         fecha         producto  categoria  cantidad  precio_unitario medida  \
# 0  2023-03-26            Pollo     Granos         5             0.95     kg
# 1  2023-11-06  Pasta de Tomate    Lácteos         2             1.50      u
# 2  2023-07-21           Bolsas  Panadería         4             0.35      u
# 3  2024-09-09            Pollo     Granos         4             0.95     kg
# 4  2024-10-25            Pollo     Granos         2             0.95     kg
#
#    total
# 0   4.75
# 1   3.00
# 2   1.40
# 3   3.80
# 4   1.90

# %% [markdown]
# 📊 Paso 2: Análisis exploratorio de ventas
# 1. Productos más vendidos (por cantidad)

# %%
top_productos = df.groupby("producto")["cantidad"].sum().sort_values(ascending=False)
print(top_productos)

# Crear el gráfico y obtener el objeto `ax`
ax = top_productos.plot(
    kind="line",
    marker="o",
    markersize=6,
    markerfacecolor="blue",
    title="Productos más vendidos por cantidad",
    ylabel="Unidades vendidas"
)

# Mostrar todas las etiquetas del eje X
ax.set_xticks(range(len(top_productos)))
ax.set_xticklabels(top_productos.index, rotation=45)

plt.tight_layout()  # Ajustar el diseño para que no se corte nada
plt.show()
# Out:
# producto
# Refresco              4827
# Yogurt                4738
# Leche entera          4672
# Pollo                 4670
# Papas precocinadas    4644
# Bolsas                4573
# Pasta de Tomate       4495
# Carne molida          4466
# Jamón                 4316
# Helado                4301
# Name: cantidad, dtype: int64

# %% [markdown]
# 2. Productos con mayor ingreso (por total en dinero)

# %%
ingresos_productos = df.groupby("producto")["total"].sum().sort_values(ascending=False)
print(ingresos_productos)

ingresos_productos.plot(kind="bar", title="Productos con mayores ingresos", ylabel="Total vendido ($)", color='green')
# Out:
# producto
# Leche entera          23360.00
# Papas precocinadas    14628.60
# Pasta de Tomate        6742.50
# Helado                 4731.10
# Pollo                  4436.50
# Jamón                  3884.40
# Carne molida           3572.80
# Yogurt                 2605.90
# Refresco               2172.15
# Bolsas                 1600.55
# Name: total, dtype: float64
# <Axes: title={'center': 'Productos con mayores ingresos'}, xlabel='producto', ylabel='Total vendido ($)'>

# %% [markdown]
# 3. Tendencia de ventas a lo largo del tiempo
# Primero convertimos la fecha a tipo datetime:

# %%
df["fecha"] = pd.to_datetime(df["fecha"])
ventas_por_mes = df.resample("ME", on="fecha")["total"].sum()

ventas_por_mes.plot(title="Tendencia mensual de ingresos", ylabel="Total mensual ($)", figsize=(10, 5))
# Out:
# <Axes: title={'center': 'Tendencia mensual de ingresos'}, xlabel='fecha', ylabel='Total mensual ($)'>

# %% [markdown]
# 4. Ventas por categoría

# %%
df.groupby("categoria")["cantidad"].sum().sort_values().plot(
    kind="barh", title="Ventas por categoría", xlabel="Cantidad vendida", color='orange'
)
# Out:
# <Axes: title={'center': 'Ventas por categoría'}, xlabel='Cantidad vendida', ylabel='categoria'>

# %% [markdown]
# Mostrar cómo se comportaron las ventas a lo largo del tiempo.

# %% [markdown]
# ✅ Fase Intermedia: Validación y limpieza básica del dataset

# %% [markdown]
# 1. Verificar valores nulos o vacíos

# %%
print(df.isnull().sum())
# Out:
# fecha              0
# producto           0
# categoria          0
# cantidad           0
# precio_unitario    0
# medida             0
# total              0
# dtype: int64

# %% [markdown]
# 2. Verificar tipos de datos

# %%
print(df.dtypes)
# Out:
# fecha              datetime64[ns]
# producto                   object
# categoria                  object
# cantidad                    int64
# precio_unitario           float64
# medida                     object
# total                     float64
# dtype: object

# %% [markdown]
# 3. Revisar valores únicos y categorías inesperadas

# %%
print(df["producto"].unique())
print(df["categoria"].value_counts())
# Out:
# ['Pollo' 'Pasta de Tomate' 'Bolsas' 'Refresco' 'Leche entera' 'Helado'
#  'Jamón' 'Papas precocinadas' 'Carne molida' 'Yogurt']
# categoria
# Lácteos      4471
# Granos       3097
# Carnes       3086
# Bebidas      1584
# Panadería    1516
# Aceites      1479
# Name: count, dtype: int64

# %% [markdown]
# 4. Detección de valores extremos o errores

# %%
print(df.describe())

# Ejemplo de outliers en cantidad
df[df["cantidad"] > 200]  #Imprime cuales valores anormales hay en las ventas
# Out:
#                                fecha      cantidad  precio_unitario  \
# count                          15233  15233.000000     15233.000000
# mean   2024-01-14 21:33:56.919845120      3.000197         1.485259
# min              2023-03-01 00:00:00      1.000000         0.350000
# 25%              2023-08-05 00:00:00      2.000000         0.550000
# 50%              2024-01-15 00:00:00      3.000000         0.900000
# 75%              2024-06-24 00:00:00      4.000000         1.500000
# max              2024-12-01 00:00:00     11.000000         5.000000
# std                              NaN      1.415907         1.417018
#
#               total
# count  15233.000000
# mean       4.446563
# min        0.350000
# 25%        1.400000
# 50%        2.700000
# 75%        4.800000
# max       40.000000
# std        5.118992
# Empty DataFrame
# Columns: [fecha, producto, categoria, cantidad, precio_unitario, medida, total]
# Index: []

# %% [markdown]
# 5. Duplicados

# %%
print(df.duplicated().sum())
print(df[df.duplicated()])
#df = df.drop_duplicates()
# Out:
# 3130
#            fecha         producto  categoria  cantidad  precio_unitario  \
# 61    2024-10-31         Refresco     Carnes         2             0.45
# 553   2024-02-17            Jamón     Carnes         4             0.90
# 599   2024-04-22  Pasta de Tomate    Lácteos         3             1.50
# 625   2023-05-10           Bolsas  Panadería         3             0.35
# 691   2023-10-18           Yogurt    Bebidas         3             0.55
# ...          ...              ...        ...       ...              ...
# 15225 2024-05-12            Jamón     Carnes         3             0.90
# 15227 2023-04-13     Leche entera     Granos         2             5.00
# 15228 2024-02-26     Leche entera     Granos         3             5.00
# 15230 2023-06-11  Pasta de Tomate    Lácteos         2             1.50
# 15232 2024-06-10     Leche entera     Granos         3             5.00
#
#       medida  total
# 61         u   0.90
# 553       kg   3.60
# 599        u   4.50
# 625        u   1.05
# 691        u   1.65
# ...      ...    ...
# 15225     kg   2.70
# 15227      u  10.00
# 15228      u  15.00
# 15230      u   3.00
# 15232      u  15.00
#
# [3130 rows x 7 columns]

# %% [markdown]
# Ahora probamos a eliminar los duplicados:

# %%
df = df.drop_duplicates()
print("Duplicados eliminados")
# Out:
# Duplicados eliminados

# %% [markdown]
# Ahora consultamos si ya no hay duplicados:

# %%
print(df.duplicated().sum())
print(df[df.duplicated()])
print("Now the dataset have:",len(df),"rows")
# Out:
# 0
# Empty DataFrame
# Columns: [fecha, producto, categoria, cantidad, precio_unitario, medida, total]
# Index: []
# Now the dataset have: 12103 rows

# %% [markdown]
# 6.Formato correcto de fechas

# %%
df["fecha"] = pd.to_datetime(df["fecha"], errors="coerce")

# %% [markdown]
# 📊 3. Transformar el dataset para modelado
# •	Necesitamos agrupar las ventas por mes y por producto:

# %%
import pandas as pd

# Cargar y preparar
df = pd.read_csv("ventas_empresa_logistica.csv", parse_dates=["fecha"])
df["año_mes"] = df["fecha"].dt.to_period("M")

# Agrupación por producto y mes
ventas_mensuales = df.groupby(["producto", "año_mes"]).agg({
    "cantidad": "sum"
}).reset_index()

# Convertimos año_mes a fecha
ventas_mensuales["fecha"] = ventas_mensuales["año_mes"].dt.to_timestamp()
ventas_mensuales = ventas_mensuales.sort_values(by=["producto", "fecha"])

print(ventas_mensuales)
# Out:
#     producto  año_mes  cantidad      fecha
# 0     Bolsas  2023-03       226 2023-03-01
# 1     Bolsas  2023-04       180 2023-04-01
# 2     Bolsas  2023-05       224 2023-05-01
# 3     Bolsas  2023-06       204 2023-06-01
# 4     Bolsas  2023-07       276 2023-07-01
# ..       ...      ...       ...        ...
# 214   Yogurt  2024-08       258 2024-08-01
# 215   Yogurt  2024-09       263 2024-09-01
# 216   Yogurt  2024-10       230 2024-10-01
# 217   Yogurt  2024-11       228 2024-11-01
# 218   Yogurt  2024-12        11 2024-12-01
#
# [219 rows x 4 columns]

# %% [markdown]
# Visualizar la evolución de ventas por producto:

# %%
import matplotlib.pyplot as plt
for producto in df["producto"].unique():

    df_prod = ventas_mensuales[ventas_mensuales["producto"] == producto]
    
    plt.plot(df_prod["fecha"], df_prod["cantidad"], marker="o")
    plt.title(f"Evolución mensual de ventas: {producto}")
    plt.xlabel("Fecha")
    plt.ylabel("Cantidad vendida")
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.show()
